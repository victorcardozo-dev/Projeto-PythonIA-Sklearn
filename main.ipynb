# %%
# Projeto Analisando um cliente
# Se o cliente é bom, ok ou ruim (Notata de crédito dele = Score de crédito)
# Passo a passo do preojeto
# passo 0 - Entender o desafio da empresa
# passo 1 - Importar a base de dados

import pandas as pd 

tabela = pd.read_csv('clientes.csv')
display(tabela)
display(tabela.info())
# Out:
#        id_cliente  mes  idade  profissao  salario_anual  num_contas  \
# 0            3392    1   23.0  cientista       19114.12         3.0
# 1            3392    2   23.0  cientista       19114.12         3.0
# 2            3392    3   23.0  cientista       19114.12         3.0
# 3            3392    4   23.0  cientista       19114.12         3.0
# 4            3392    5   23.0  cientista       19114.12         3.0
# ...           ...  ...    ...        ...            ...         ...
# 99995       37932    4   25.0   mecanico       39628.99         4.0
# 99996       37932    5   25.0   mecanico       39628.99         4.0
# 99997       37932    6   25.0   mecanico       39628.99         4.0
# 99998       37932    7   25.0   mecanico       39628.99         4.0
# 99999       37932    8   25.0   mecanico       39628.99         4.0
#
#        num_cartoes  juros_emprestimo  num_emprestimos  dias_atraso  ...  \
# 0              4.0               3.0              4.0          3.0  ...
# ...

# %%
# passo 2 - Tratar e preparar a base de dados para a inteligencia artificial
# IA só consegue trabalhar com números (precisa transformar todos os dados que são texto para números)
    # OBS - Só a cluna que voce quer prever que pode ficar como string

from sklearn.preprocessing import LabelEncoder


# profissao
codificador_profissao = LabelEncoder()
tabela['profissao'] = codificador_profissao.fit_transform(tabela['profissao'])

# mix_credito
codificador_mix_credito = LabelEncoder()
tabela['mix_credito'] = codificador_mix_credito.fit_transform(tabela['mix_credito'])

# comportamento_pagamento
codificador_comportamento_pagamento = LabelEncoder()
tabela['comportamento_pagamento'] = codificador_comportamento_pagamento.fit_transform(tabela['comportamento_pagamento'])

display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id_cliente                100000 non-null  int64
#  1   mes                       100000 non-null  int64
#  2   idade                     100000 non-null  float64
#  3   profissao                 100000 non-null  int64
#  4   salario_anual             100000 non-null  float64
#  5   num_contas                100000 non-null  float64
#  6   num_cartoes               100000 non-null  float64
#  7   juros_emprestimo          100000 non-null  float64
#  8   num_emprestimos           100000 non-null  float64
#  9   dias_atraso               100000 non-null  float64
#  10  num_pagamentos_atrasados  100000 non-null  float64
#  11  num_verificacoes_credito  100000 non-null  float64
#  12  mix_credito               100000 non-null  int64
# ...

# %%
#Como funciona o processo de criação de uma IA 
# Precisa definir quem eu quero prever - (a coluna score_credito = y)

# Y é quem eu vou prever
y = tabela['score_credito']

# X é quem eu vou usar para fazer a previsão - (o restante da tabela sem os dados inúteis e sem o Y também)
x = tabela.drop(columns=['id_cliente', 'score_credito'])


#importar a funçaõ que vai separar os dados para treino e teste
from sklearn.model_selection import train_test_split

# separar em dados de treino e dados de teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y)

# %%
# passo 3 - Criar o modelo de previsão ou o modelo de -> IA - (Ruim, Ok, Boa)

# Modelo arvore de decisao - RandomForest 
# Modelo KNN - Nearest Neighbors -> Vizinhos próximos

# Importar a IA (modelo)
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Criar a IA (modelo)
modelo_arvore = RandomForestClassifier()
modelo_knn = KNeighborsClassifier()

# Treinar a IA (modelo)

modelo_arvore.fit(x_treino, y_treino)
modelo_knn.fit(x_treino, y_treino)
# Out:
# KNeighborsClassifier()

# %%
# passo 4 - Avaliar e escolher o melhor modelo
# previsao
previsao_arvore = modelo_arvore.predict(x_teste)
previsao_knn = modelo_knn.predict(x_teste)

# comparar a previsao dos modelos com o y_teste
# precisa importar a função que faz a comparação dos resultados
from sklearn.metrics import accuracy_score

display(f'Modelo Random Forest = {accuracy_score(y_teste, previsao_arvore):.1%} de certeza na previsão.')
display(f'Modelo KNeighbors = {accuracy_score(y_teste, previsao_knn):.1%} de certeza na previsão.')
# Out:
# 'Modelo Random Forest = 82.7% de certeza na previsão.'
# 'Modelo KNeighbors = 74.4% de certeza na previsão.'

# %%
# passo 5 - Fazer novas previsões

# Esolher o melhor modelo = árvore de decisao

# Importar os novos clientes - e tratar os dados

novos_clientes = pd.read_csv('novos_clientes.csv')

# Usando o mesmo codificador
novos_clientes['profissao'] = codificador_profissao.transform(novos_clientes['profissao'])
novos_clientes['mix_credito'] = codificador_mix_credito.transform(novos_clientes['mix_credito'])
novos_clientes['comportamento_pagamento'] = codificador_comportamento_pagamento.transform(novos_clientes['comportamento_pagamento'])

# Fazer a previsao dos novos clientes
display(f'Resultado com o modelo Random Forest- {modelo_arvore.predict(novos_clientes)}')
display(f'Resultado com o modelo KNeighbors- {modelo_knn.predict(novos_clientes)}')
# Out:
# "Resultado com o modelo Random Forest- ['Poor' 'Poor' 'Standard']"
# "Resultado com o modelo KNeighbors- ['Poor' 'Poor' 'Standard']"
